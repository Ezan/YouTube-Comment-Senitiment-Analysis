# %%
import numpy as np 
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
import matplotlib.pyplot as plt
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from wordcloud import WordCloud
import re
import seaborn as sn
from nltk.stem import WordNetLemmatizer
from nltk.stem.snowball import SnowballStemmer
# %matplotlib inline

# %%
import os
import string

# %%
train = pd.read_csv('imdb.csv', encoding = "ISO-8859-1", engine='python')
train.head(10)
# Out:
#    Unnamed: 0  type                                             review label  \
# 0           0  test  Once again Mr. Costner has dragged out a movie...   neg
# 1           1  test  This is an example of why the majority of acti...   neg
# 2           2  test  First of all I hate those moronic rappers, who...   neg
# 3           3  test  Not even the Beatles could write songs everyon...   neg
# 4           4  test  Brass pictures (movies is not a fitting word f...   neg
# 5           5  test  A funny thing happened to me while watching "M...   neg
# 6           6  test  This German horror film has to be one of the w...   neg
# 7           7  test  Being a long-time fan of Japanese film, I expe...   neg
# 8           8  test  "Tokyo Eyes" tells of a 17 year old Japanese g...   neg
# 9           9  test  Wealthy horse ranchers in Buenos Aires have a ...   neg
#
#           file
# 0      0_2.txt
# 1  10000_4.txt
# 2  10001_1.txt
# 3  10002_3.txt
# 4  10003_3.txt
# 5  10004_2.txt
# 6  10005_2.txt
# 7  10006_2.txt
# 8  10007_4.txt
# 9  10008_4.txt

# %%
train=train[['review','label']]
train = train[train.label != "unsup"]
train['label'].value_counts()
train.head(10)
# Out:
#                                               review label
# 0  Once again Mr. Costner has dragged out a movie...   neg
# 1  This is an example of why the majority of acti...   neg
# 2  First of all I hate those moronic rappers, who...   neg
# 3  Not even the Beatles could write songs everyon...   neg
# 4  Brass pictures (movies is not a fitting word f...   neg
# 5  A funny thing happened to me while watching "M...   neg
# 6  This German horror film has to be one of the w...   neg
# 7  Being a long-time fan of Japanese film, I expe...   neg
# 8  "Tokyo Eyes" tells of a 17 year old Japanese g...   neg
# 9  Wealthy horse ranchers in Buenos Aires have a ...   neg

# %%
train['label'].value_counts().plot(kind='bar')

# %%
train.shape
# Out:
# (50000, 2)

# %%
train.columns
# Out:
# Index(['review', 'label'], dtype='object')

# %%
stop_list=["film","movie","story","character","show","scene","director","actors","br","watch","see"]
stopwords_set = set(stopwords.words("english")+stop_list)
stemmer=SnowballStemmer('english')
def cleaner(text):
    #text = re.sub('http:?.+|\@.+: ', '', text)
    #text = ''.join([i for i in text if not i.isdigit()])
    # Clean punctuation and symbols
    text = re.sub("[!@#$+<>&%\"*:();'-']", ' ', text)
    #text=[lemmatizer.lemmatize(word) for word in text if not word in stopwords_set]
    #re.sub('[^A-Za-z0-9]+', '', "Hello $#! People   Whitespace 7331")
    words_filtered = [e.lower() for e in text.split() if len(e)>=3]
    words_cleaned = [word for word in words_filtered
            if 'film' not in word
            if 'movie' not in word
            if 'story' not in word
            if 'show' not in word
            if 'character' not in word
            if 'scene' not in word
            if 'actor' not in word
            if 'director' not in word
            if 'play' not in word
            if 'watch' not in word
            and not word.startswith('@') 
            and not word.startswith('#')]
    words_without_stopwords = [stemmer.stem(word) for word in words_cleaned if not word in stopwords_set]
    return " ".join(words_without_stopwords)

# %%
cleaner('film movie story character show scene director actors br')
# Out:
# ''

# %%
train['cleaned']= train['review'].apply(lambda x : cleaner(x))

# %%
train.head()
# Out:
#                                               review label  \
# 0  Once again Mr. Costner has dragged out a movie...   neg
# 1  This is an example of why the majority of acti...   neg
# 2  First of all I hate those moronic rappers, who...   neg
# 3  Not even the Beatles could write songs everyon...   neg
# 4  Brass pictures (movies is not a fitting word f...   neg
#
#                                              cleaned  sentiment_no
# 0  mr. costner drag far longer necessary. asid te...             0
# 1  exampl major action same. generic boring, real...             0
# 2  first hate moron rappers, could act gun press ...             0
# 3  even beatl could write song everyon liked, alt...             0
# 4  brass pictur fit word realli somewhat brassy. ...             0

# %%
def dict(x) :
    if x=='pos':
        return 1
    else:
        return 0

# %%
train['sentiment_no']=train['label'].apply(lambda x: dict(x))

# %%
print (train.shape)
# Out:
# (50000, 4)

# %%
train.head(10)
# Out:
#                                               review label  \
# 0  Once again Mr. Costner has dragged out a movie...   neg
# 1  This is an example of why the majority of acti...   neg
# 2  First of all I hate those moronic rappers, who...   neg
# 3  Not even the Beatles could write songs everyon...   neg
# 4  Brass pictures (movies is not a fitting word f...   neg
# 5  A funny thing happened to me while watching "M...   neg
# 6  This German horror film has to be one of the w...   neg
# 7  Being a long-time fan of Japanese film, I expe...   neg
# 8  "Tokyo Eyes" tells of a 17 year old Japanese g...   neg
# 9  Wealthy horse ranchers in Buenos Aires have a ...   neg
#
#                                              cleaned  sentiment_no
# 0  mr. costner drag far longer necessary. asid te...             0
# 1  exampl major action same. generic boring, real...             0
# 2  first hate moron rappers, could act gun press ...             0
# 3  even beatl could write song everyon liked, alt...             0
# 4  brass pictur fit word realli somewhat brassy. ...             0
# 5  funni thing happen mosquito one hand, hero dea...             0
# 6  german horror one weirdest seen. awar connect ...             0
# 7  long-tim fan japanes expect this. realli bothe...             0
# 8  tokyo eye tell year old japanes girl fall like...             0
# 9  wealthi hors rancher bueno air long-stand no-t...             0

# %%
train_data=train.sample(frac=0.8)
test_data=train.drop(train_data.index)
train_data.head(10)
# Out:
#                                                   review label  \
# 8185   UGH!...this is the worst Wrestlemania hands do...   neg
# 846    Though it's better than most made-for-TV movie...   neg
# 1248   Chupacabra: Dark Waters has to rank as one of ...   neg
# 36891  Holy cow, what a piece of sh*t this movie is. ...   neg
# 4101   A British teen movies which centres around a g...   neg
# 44738  I can remember watching this for the first tim...   pos
# 30776  I cheer for films that fill in subject matter ...   neg
# 11299  Steven Seagal is a thief who specializes in ro...   neg
# 20046  What happened to Ava Gardner in the 1940s and ...   pos
# 12384  I wish I had read the comments on IMDb before ...   neg
#
#                                                  cleaned  sentiment_no
# 8185   ugh ...this worst wrestlemania hand down....no...             0
# 846    though better made-for-tv buri aliv noth run-o...             0
# 1248   chupacabra dark water rank one insipid moron e...             0
# 36891  holi cow, piec is. could take 250 word book tu...             0
# 4101   british teen centr around girl justin accident...             0
# 44738  rememb first time, year old. want one barbaria...             1
# 30776  cheer fill subject matter gap world cinema. tr...             0
# 11299  steven seagal thief special rob wealther drug ...             0
# 20046  happen ava gardner 1940s marilyn monro 50s als...             1
# 12384  wish read comment imdb saw first hour ok, thou...             0

# %%
test_data.head(10)
# Out:
#                                                review label  \
# 0   Once again Mr. Costner has dragged out a movie...   neg
# 3   Not even the Beatles could write songs everyon...   neg
# 11  First of all, I would like to say that I am a ...   neg
# 26  Everything everyone has said already pretty mu...   neg
# 31  Foolish hikers go camping in the Utah mountain...   neg
# 43  I am not understanding why people are praising...   neg
# 50  I saw this movie yesterday and thought it was ...   neg
# 65  I have never seen so much talent and money use...   neg
# 66  Three businessmen are involved in a bar fight ...   neg
# 76  <br /><br />JURASSIC PARK III *___ Adventure <...   neg
#
#                                               cleaned  sentiment_no
# 0   mr. costner drag far longer necessary. asid te...             0
# 3   even beatl could write song everyon liked, alt...             0
# 11  first all, would like say fan appear time rent...             0
# 26  everyth everyon said alreadi pretti much ring ...             0
# 31  foolish hiker camp utah mountain run murderous...             0
# 43  understand peopl prais like all. sever people....             0
# 50  saw yesterday thought aw pointless plain stupi...             0
# 65  never seen much talent money use produc anyth ...             0
# 66  three businessmen involv bar fight three myste...             0
# 76  jurass park iii ___ adventur sam nell dish wil...             0

# %%
train_data['sentiment_no'].value_counts().plot(kind = 'bar')

# %%
test_data['sentiment_no'].value_counts().plot(kind='bar')

# %%
pos_comments = ' '.join(list(train_data[train_data['sentiment_no'] == 1]['cleaned']))
spam_wc = WordCloud(width = 512,height = 512).generate(pos_comments)
plt.figure(figsize = (10, 8), facecolor = 'k')
plt.imshow(spam_wc)
plt.axis('off')
plt.tight_layout(pad = 0)
plt.show()

# %%
neg_comments = ' '.join(list(train_data[train_data['sentiment_no'] == 0]['cleaned']))
spam_wc = WordCloud(width = 512,height = 512).generate(neg_comments)
plt.figure(figsize = (10, 8), facecolor = 'k')
plt.imshow(spam_wc)
plt.axis('off')
plt.tight_layout(pad = 0)
plt.show()

# %%
test_data['sentiment_no'].value_counts().plot(kind = 'bar')

# %%
tfidf_vect=TfidfVectorizer(stop_words='english', max_df=0.5)
tfidf_train=tfidf_vect.fit_transform(train_data['cleaned'])
train_label = train_data['sentiment_no']
# tfidf_test=tfidf_vect.transform(x_test)

# %%
print ("feature names: ", tfidf_vect.get_feature_names()[:10])
# Out:
# feature names:  ['00', '000', '00000000000', '0000000000001', '00000001', '00001', '00015', '000dm', '000s', '001']

# %%
nb_class=MultinomialNB(alpha=0.01)
nb_class.fit(tfidf_train,train_label)
# Out:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)

# %%
predictions = nb_class.predict(tfidf_vect.transform(test_data['review']))

# %%
## accurcay
np.mean(predictions == test_data['sentiment_no'])
# Out:
# 0.8176

# %%
cm=metrics.confusion_matrix(test_data['sentiment_no'],predictions)
print ("Confusion marix: \n", cm)
# Out:
# Confusion marix:
#  [[4018  961]
#  [ 863 4158]]

# %%
ax=sn.heatmap(cm, annot=True,fmt='d')
ax.set(xlabel='neg                     pos', ylabel='pos                   neg')
# Out:
# [Text(33.0, 0.5, 'pos                   neg'),
#  Text(0.5, 15.0, 'neg                     pos')]

# %%
test = pd.read_csv('scrape.csv')
test['cleaned'] = test['comment_text'].apply(lambda x : cleaner(x))

# %%
predictions = nb_class.predict(tfidf_vect.transform(test['cleaned']))

# %%
test['predicted']=predictions

# %%
test.to_csv('youtube_output.csv')

# %%
def predictor(text) :
    text=cleaner(text)
    return nb_class.predict(tfidf_vect.transform([text]))

# %%
predictor("the movie was exceptionally well scripted but aweful execution made it worse ")
# Out:
# array([0], dtype=int64)

# %%
tfidf_vect.transform(["even one end people"])
# Out:
# <1x86631 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2 stored elements in Compressed Sparse Row format>

# %%
prediction_result=pd.read_csv('youtube_output.csv')
prediction_result.head(20)
# Out:
#     Unnamed: 0  id                                       comment_text  \
# 0            0   0       who else has this song stuck in there head??
# 1            1   1  my girl: why do u actually love me?     me: be...
# 2            2   2                           5 time watching anyone ?
# 3            3   3                       it's not a song it's a vibe.
# 4            4   4  well..at least it's not glorifying ho's cocain...
# 5            5   5  can we take a moment to appreciate how much of...
# 6            6   6  like this if youre listening in february 2019!!!😍
# 7            7   7                                    rip stan lee :(
# 8            8   8  i really need 2 part of (spider-man into the s...
# 9            9   9  i mean this song should have been played in th...
# 10          10  10  baby i'm a wreck . someone took a very big l a...
# 11          11  11             dang 71k people missed the like button
# 12          12  12     mj and peter's broken love story makes me sad.
# 13          13  13        like if post malone is better than lil pump
# 14          14  14  i mean i don't fancy post malone but why does ...
# 15          15  15                                              2019?
# 16          16  16                   good job who  ever made the song
# 17          17  17                                  who cuttin onions
# 18          18  18  cant stop listening and its 6/2 2019  anyone e...
# 19          19  19               1b views is deserving for this video
#
#                                               cleaned  predicted
# 0                               els song stuck head??          0
# 1                    girl actual love me? sunflower..          1
# 2                                          time anyon          0
# 3                                          song vibe.          1
# 4        well..at least glorifi cocain uzi well done.          0
# 5        take moment appreci much masterpiec song is?          1
# 6                      like your listen februari 2019          1
# 7                                        rip stan lee          0
# 8   realli need part spider-man spider vers like w...          0
# 9                               mean song super bowl.          1
# 10               babi wreck someon took big know felt          0
# 11                    dang 71k peopl miss like button          0
# 12                        peter broken love make sad.          1
# 13                    like post malon better lil pump          1
# 14        mean fanci post malon video 70k thumb down?          1
# 15                                              2019?          1
# 16                            good job ever made song          1
# 17                                       cuttin onion          0
# 18            cant stop listen 6/2 2019 anyon els ???          1
# 19                                  view deserv video          1

# %%
def reverse_dict(x) :
    if x=='1':
        return "pos"
    else:
        return "neg"
